# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn import metrics
from sklearn.model_selection import cross_validate

# %% [markdown]
# ## Reading the data

# %%
#Reading the training data
train_df = pd.read_csv('train.csv')

#Reading the testing data
test_df = pd.read_csv('test.csv')

# %%
#Let's see the head of the training data
train_df.head()
# Out:
#    Id  carat      cut color clarity  depth  table  price     x     y     z
# 0   1   1.06    Ideal     I     SI2   61.8   57.0   4270  6.57  6.60  4.07
# 1   2   1.51  Premium     G    VVS2   60.9   58.0  15164  7.38  7.42  4.51
# 2   3   0.32    Ideal     F     VS2   61.3   56.0    828  4.43  4.41  2.71
# 3   4   0.53    Ideal     G     VS2   61.2   56.0   1577  5.19  5.22  3.19
# 4   5   0.70  Premium     H    VVS2   61.0   57.0   2596  5.76  5.72  3.50

# %%
#Let's see the head of the testing data
test_df.head()
#We can notice that the price is not there as it is our job to predict it
# Out:
#    Id  carat        cut color clarity  depth  table     x     y     z
# 0   1   0.34      Ideal     G    VVS2   61.1   57.0  4.52  4.48  2.75
# 1   2   0.71    Premium     E     VS2   62.7   58.0  5.74  5.68  3.58
# 2   3   0.44  Very Good     I     VS1   62.8   56.0  4.83  4.88  3.05
# 3   4   0.81    Premium     E     SI2   60.1   59.0  6.09  6.03  3.65
# 4   5   0.40      Ideal     G    VVS1   61.2   56.0  4.74  4.80  2.92

# %%
#Let's see the shape of the train data
print('Train Data shape: ', train_df.shape)

#Let's see the shape of the test data
print('Test Data shape: ', test_df.shape)
# Out:
# Train Data shape:  (43152, 11)
# Test Data shape:  (10788, 10)

# %%
#Let's see the info of the train data
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43152 entries, 0 to 43151
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       43152 non-null  int64
#  1   carat    43152 non-null  float64
#  2   cut      43152 non-null  object
#  3   color    43152 non-null  object
#  4   clarity  43152 non-null  object
#  5   depth    43152 non-null  float64
#  6   table    43152 non-null  float64
#  7   price    43152 non-null  int64
#  8   x        43152 non-null  float64
#  9   y        43152 non-null  float64
#  10  z        43152 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 3.6+ MB

# %%
#Let's see the describtion of the train data
train_df.describe()
# Out:
#                  Id         carat         depth         table         price  \
# count  43152.000000  43152.000000  43152.000000  43152.000000  43152.000000
# mean   21576.500000      0.797855     61.747177     57.458347   3929.491912
# std    12457.053745      0.473594      1.435454      2.233904   3985.527795
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    10788.750000      0.400000     61.000000     56.000000    947.750000
# 50%    21576.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    32364.250000      1.040000     62.500000     59.000000   5312.000000
# max    43152.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  43152.000000  43152.000000  43152.000000
# mean       5.731568      5.735018      3.538568
# std        1.121279      1.148809      0.708238
# min        0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.040000
# max       10.740000     58.900000     31.800000

# %% [markdown]
# ### Checking for null data

# %%
#Let's see if we have null data
train_df.isna().sum()
#As we can see, we do not have null data in our dataset
# Out:
# Id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
#Let's see the columns in the train data
train_df.columns
# Out:
# Index(['Id', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price',
#        'x', 'y', 'z'],
#       dtype='object')

# %% [markdown]
# ## Id

# %%
#We do not need the Id column as it will not give us any value, so I am going to drop it
train_df.drop(['Id'], axis=1, inplace=True)

# %% [markdown]
# ### Checking for duplicated data

# %%
#Let's see if there is duplicated data
train_df.duplicated().sum()
#As we can see we have some duplicated data, so we have to drop them
# Out:
# 97

# %%
#Let's drop the duplicated data
train_df.drop_duplicates(inplace=True)

# %%
#Let's check the shape of the data after dropping the duplicated data
train_df.shape
# Out:
# (43055, 10)

# %% [markdown]
# ## carat

# %% [markdown]
# **Carat refers to the weight of the diamond, which is an important factor in determining its price.**

# %%
# Let's see the describtion 
carat_stats = train_df['carat'].describe()
print("Carat Statistics:")
print(carat_stats)
# Out:
# Carat Statistics:
# count    43055.000000
# mean         0.797752
# std          0.473198
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64

# %%
carat_counts = train_df['carat'].value_counts().sum()
carat_counts
# Out:
# 43055

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=train_df, x='carat', kde=True)
plt.title(f"Histogram of {'carat'}")
plt.show()

# %% [markdown]
# ## cut

# %% [markdown]
# **Cut refers to the quality of how the diamond is cut, affecting its brilliance and overall appearance.**

# %%
# Let's see the describtion 
cut_stats = train_df['cut'].describe()
print("Cut Statistics:")
print(cut_stats)
# Out:
# Cut Statistics:
# count     43055
# unique        5
# top       Ideal
# freq      17161
# Name: cut, dtype: object

# %%
#Let's see the value counts of cut
cut_counts = train_df['cut'].value_counts()
print("\nCut Counts:")
print(cut_counts)
# Out:
# Cut Counts:
# cut
# Ideal        17161
# Premium      11080
# Very Good     9651
# Good          3874
# Fair          1289
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=train_df, x='cut', kde=True)
plt.title(f"Histogram of {'cut'}")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=train_df, x='cut')
plt.title(f"Countplot of {'cut'}")
plt.show()

# %% [markdown]
# ## color

# %% [markdown]
# **Color represents the diamond's color grade, ranging from D (colorless) to Z (light yellow or brown).**

# %%
# Let's see the describtion 
color_stats = train_df['color'].describe()
print("Color Statistics:")
print(color_stats)
# Out:
# Color Statistics:
# count     43055
# unique        7
# top           G
# freq       9042
# Name: color, dtype: object

# %%
color_counts = train_df['color'].value_counts()
print("\nColor Counts:")
print(color_counts)
# Out:
# Color Counts:
# color
# G    9042
# E    7817
# F    7616
# H    6629
# D    5411
# I    4254
# J    2286
# Name: count, dtype: int64

# %%
#Let's see the colors 
plt.figure(figsize=(8, 5))
sns.countplot(data=train_df, x='color')
plt.title(f"Countplot of {'color'}")
plt.show()

# %% [markdown]
# ## clarity

# %% [markdown]
# **Clarity refers to the presence of internal or external flaws in the diamond. It is usually graded on a scale from IF (internally flawless) to I3 (included).**

# %%
# Let's see the describtion 
clarity_stats = train_df['clarity'].describe()
print("Clarity Statistics:")
print(clarity_stats)
# Out:
# Clarity Statistics:
# count     43055
# unique        8
# top         SI1
# freq      10406
# Name: clarity, dtype: object

# %%
clarity_counts = train_df['clarity'].value_counts()
print("\nClarity Counts:")
print(clarity_counts)
# Out:
# Clarity Counts:
# clarity
# SI1     10406
# VS2      9806
# SI2      7403
# VS1      6465
# VVS2     4031
# VVS1     2899
# IF       1440
# I1        605
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=train_df, x='clarity')
plt.title(f"Countplot of {'clarity'}")
plt.show()

# %% [markdown]
# ## depth

# %% [markdown]
# **Depth represents the height of a diamond as a percentage of its diameter.**

# %%
# Let's see the describtion 
depth_stats = train_df['depth'].describe()
print("depth Statistics:")
print(depth_stats)
# Out:
# depth Statistics:
# count    43055.000000
# mean        61.746373
# std          1.435066
# min         43.000000
# 25%         61.000000
# 50%         61.800000
# 75%         62.500000
# max         79.000000
# Name: depth, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=train_df, x='depth', kde=True)
plt.title(f"Histogram of {'depth'}")
plt.show()

# %% [markdown]
# ## table

# %% [markdown]
# **Table refers to the width of the diamond's top facet as a percentage of its diameter.**

# %%
# Let's see the describtion 
table_stats = train_df['table'].describe()
print("Table Statistics:")
print(table_stats)
# Out:
# Table Statistics:
# count    43055.000000
# mean        57.459798
# std          2.234325
# min         43.000000
# 25%         56.000000
# 50%         57.000000
# 75%         59.000000
# max         95.000000
# Name: table, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=train_df, x='table', kde=True)
plt.title(f"Histogram of {'table'}")
plt.show()

# %% [markdown]
# ## price

# %% [markdown]
# **This column contains the target variable, i.e., the price of the diamond.**

# %%
# Let's see the describtion 
price_stats = train_df['price'].describe()
print("Price Statistics:")
print(price_stats)
# Out:
# Price Statistics:
# count    43055.000000
# mean      3930.016235
# std       3984.939986
# min        326.000000
# 25%        948.000000
# 50%       2401.000000
# 75%       5312.500000
# max      18823.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=train_df, x='price', kde=True)
plt.title(f"Histogram of {'price'}")
plt.show()

# %% [markdown]
# ## x

# %% [markdown]
# **This column represent the dimensions of the diamond in length.**

# %%
# Let's see the describtion 
x_stats = train_df['x'].describe()
print("X Statistics:")
print(x_stats)
#we can notice that the min is 0
# Out:
# X Statistics:
# count    43055.000000
# mean         5.731555
# std          1.120732
# min          0.000000
# 25%          4.710000
# 50%          5.700000
# 75%          6.540000
# max         10.740000
# Name: x, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=train_df, x='x', kde=True)
plt.title(f"Histogram of {'x'}")
plt.show()

# %% [markdown]
# ## y

# %% [markdown]
# **This column represent the dimensions of the diamond in width.**

# %%
# Let's see the describtion 
y_stats = train_df['y'].describe()
print("Y Statistics:")
print(y_stats)
#we can notice that the min is 0
# Out:
# Y Statistics:
# count    43055.000000
# mean         5.735063
# std          1.148389
# min          0.000000
# 25%          4.720000
# 50%          5.710000
# 75%          6.540000
# max         58.900000
# Name: y, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=train_df, x='y', kde=True)
plt.title(f"Histogram of {'y'}")
plt.show()

# %% [markdown]
# ## z

# %% [markdown]
# **This column represent the dimensions of the diamond in depth.**

# %%
# Let's see the describtion 
z_stats = train_df['z'].describe()
print("z Statistics:")
print(z_stats)
#we can notice that the min is 0
# Out:
# z Statistics:
# count    43055.000000
# mean         3.538528
# std          0.707922
# min          0.000000
# 25%          2.910000
# 50%          3.530000
# 75%          4.040000
# max         31.800000
# Name: z, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=train_df, x='y', kde=True)
plt.title(f"Histogram of {'y'}")
plt.show()

# %% [markdown]
# ### Dealing with the 0 values in x, y, z

# %%
train_df = train_df[(train_df['x'] != 0) & (train_df['y'] != 0) & (train_df['z'] != 0)]

# %%
train_df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  43038.000000  43038.000000  43038.000000  43038.000000  43038.000000
# mean       0.797475     61.746582     57.459375   3928.189112      5.731744
# std        0.472928      1.434702      2.233822   3982.731057      1.118784
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    948.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5311.750000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  43038.000000  43038.000000
# mean       5.735116      3.539926
# std        1.146848      0.704559
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %% [markdown]
# ## Visualization

# %%
# plt.figure(figsize=(20, 20))
sns.heatmap(train_df.corr(numeric_only=True), vmin=-1, vmax=1, cmap="coolwarm", annot=True, fmt=".2f")
# Out:
# <Axes: >

# %%
sns.pairplot(train_df)
# Out:
# C:\Users\habob\anaconda3\Lib\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)

# %%
# Select columns for visualization
columns_to_visualize = ['cut', 'color', 'clarity', 'carat', 'depth', 'table', 'price', 'x', 'y', 'z']

# Plot categorical columns
for column in ['cut', 'color', 'clarity']:
    plt.figure(figsize=(8, 5))
    sns.countplot(data=train_df, x=column)
    plt.title(f"Countplot of {column}")
    plt.show()

# Plot numerical columns
for column in ['carat', 'depth', 'table', 'price', 'x', 'y', 'z']:
    plt.figure(figsize=(8, 5))
    sns.histplot(data=train_df, x=column, kde=True)
    plt.title(f"Histogram of {column}")
    plt.show()

# %% [markdown]
# ## Checking for outliers

# %%
# Define a list of columns to check for outliers
columns_to_check = ['carat', 'depth', 'table', 'price', 'x', 'y', 'z']

# Detect and visualize outliers for each column
for column in columns_to_check:
    # Calculate the interquartile range (IQR)
    Q1 = train_df[column].quantile(0.25)
    Q3 = train_df[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define the outlier threshold
    lower_threshold = Q1 - 1.5 * IQR
    upper_threshold = Q3 + 1.5 * IQR

    # Find the outliers
    outliers = train_df[(train_df[column] < lower_threshold) | (train_df[column] > upper_threshold)]

    # Print the number of outliers
    print(f"Number of outliers in {column}: {len(outliers)}")

    # Create a boxplot to visualize the distribution and outliers
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=train_df, x=column)
    plt.title(f"Boxplot of {column}")
    plt.show()
# Out:
# Number of outliers in carat: 1487
# Number of outliers in depth: 2042
# Number of outliers in table: 471
# Number of outliers in price: 2830
# Number of outliers in x: 16
# Number of outliers in y: 15
# Number of outliers in z: 22

# %% [markdown]
# ## Dealing with outliers

# %%
#Let's drop the outliers 
train_df=train_df[(train_df["depth"]<70)&(train_df["depth"]>55)]
train_df=train_df[(train_df["table"]<70)&(train_df["table"]>55)]
train_df=train_df[(train_df["carat"]<3)]
train_df=train_df[(train_df["x"]<10)]
train_df=train_df[(train_df["y"])<10]
train_df=train_df[(train_df["z"]<5)&(train_df["z"]>2)]
train_df.shape
# Out:
# (34089, 10)

# %% [markdown]
# **Let's check the columns after deleting the outliers**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Define a list of columns to check for outliers
columns_to_check = ['carat', 'depth', 'table', 'price', 'x', 'y', 'z']

# Detect and visualize outliers for each column
for column in columns_to_check:
    # Calculate the interquartile range (IQR)
    Q1 = train_df[column].quantile(0.25)
    Q3 = train_df[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define the outlier threshold
    lower_threshold = Q1 - 1.5 * IQR
    upper_threshold = Q3 + 1.5 * IQR

    # Find the outliers
    outliers = train_df[(train_df[column] < lower_threshold) | (train_df[column] > upper_threshold)]

    # Print the number of outliers
    print(f"Number of outliers in {column}: {len(outliers)}")

    # Create a boxplot to visualize the distribution and outliers
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=train_df, x=column)
    plt.title(f"Boxplot of {column}")
    plt.show()
# Out:
# Number of outliers in carat: 477
# Number of outliers in depth: 1344
# Number of outliers in table: 914
# Number of outliers in price: 1687
# Number of outliers in x: 0
# Number of outliers in y: 0
# Number of outliers in z: 0

# %% [markdown]
# **As we can notice from the box plots, the outliers are deleted.**

# %% [markdown]
# ## Categorical columns

# %%
# Identify categorical columns
categorical_columns = train_df.select_dtypes(include=['object']).columns

# Print the categorical columns
print("Categorical Columns:")
print(categorical_columns)
#As we can see we have three categorical columns
# Out:
# Categorical Columns:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
train_df['clarity'].unique()
# Out:
# array(['SI2', 'VVS2', 'VS2', 'IF', 'VS1', 'SI1', 'VVS1', 'I1'],
#       dtype=object)

# %% [markdown]
# ## Dealing with Categorical columns

# %% [markdown]
# **Listed below are the diamond color grades (from 'D' to 'J') in descending order of importance, with 'D' being the most important and 'J' being the least important:**
#
# -D: Colorless
# -E: Colorless
# -F: Colorless
# -G: Near Colorless
# -H: Near Colorless
# -I: Near Colorless
# -J: Near Colorless

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler

cat = ['color','cut', 'clarity']
cat = ['color','clarity']
color = ['D', 'E', 'F', 'G', 'H', 'I', 'J']
cut = ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']
clarity = ['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1']

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

column_trans = make_column_transformer((OrdinalEncoder(categories= [color,clarity]),cat),remainder='passthrough',verbose_feature_names_out=False) # MinMaxScaler()

column_trans=column_trans.set_output(transform="pandas")

# %%
column_trans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ordinalencoder',
#                                  OrdinalEncoder(categories=[['D', 'E', 'F', 'G',
#                                                              'H', 'I', 'J'],
#                                                             ['IF', 'VVS1',
#                                                              'VVS2', 'VS1',
#                                                              'VS2', 'SI1',
#                                                              'SI2', 'I1']]),
#                                  ['color', 'clarity'])],
#                   verbose_feature_names_out=False)

# %% [markdown]
# ### Scaler

# %%
scaler = MinMaxScaler()

# %% [markdown]
# ## Splitting the data to X and y

# %%
X = train_df.drop(columns=["price"])
y = train_df.price

# %%
#Let's see X
X.head()
# Out:
#    carat color clarity  width
# 0   1.06     I     SI2   6.60
# 1   1.51     G    VVS2   7.42
# 2   0.32     F     VS2   4.41
# 3   0.53     G     VS2   5.22
# 4   0.70     H    VVS2   5.72

# %%
#Let's see the shape of X
X.shape
# Out:
# (43123, 4)

# %%
#Let's see y
y.head()
# Out:
# 0     4270
# 1    15164
# 2      828
# 3     1577
# 4     2596
# Name: price, dtype: int64

# %%
#Let's see the shape of y
y.shape
# Out:
# (43123,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=101
)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (34498, 4)
# Train target shape   :  (34498,)
# Test features shape  :  (8625, 4)
# Test target shape    :  (8625,)

# %%
def train_val(model, X_train, y_train, X_test, y_test):

    y_pred = model.predict(X_test)
    y_train_pred = model.predict(X_train)

    scores = {"train": {"R2" : r2_score(y_train, y_train_pred),
                        "mae" : mean_absolute_error(y_train, y_train_pred),
                        "mse" : mean_squared_error(y_train, y_train_pred),
                        "rmse" : mean_squared_error(y_train, y_train_pred, squared=False)},
              "test": {"R2" : r2_score(y_test, y_pred),
                       "mae" : mean_absolute_error(y_test, y_pred),
                       "mse" : mean_squared_error(y_test, y_pred),
                       "rmse" : mean_squared_error(y_test, y_pred, squared=False)}}

    return pd.DataFrame(scores)

# %% [markdown]
# ## LinearRegression Model

# %%
from sklearn.pipeline import Pipeline

operations = [
    ("ordinal", column_trans),
    ('scaler', scaler),
    ("linear",LinearRegression(fit_intercept=True, 
#     normalize=False,  
#     copy_X=True,  
    n_jobs=9))
]

pipe_linear_model = Pipeline(steps=operations)

pipe_linear_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('ordinal',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['D',
#                                                                               'E',
#                                                                               'F',
#                                                                               'G',
#                                                                               'H',
#                                                                               'I',
#                                                                               'J'],
#                                                                              ['IF',
#                                                                               'VVS1',
#                                                                               'VVS2',
#                                                                               'VS1',
#                                                                               'VS2',
#                                                                               'SI1',
#                                                                               'SI2',
#                                                                               'I1']]),
#                                                   ['color', 'clarity'])],
#                                    verbose_feature_names_out=False)),
#                 ('scaler', MinMaxScaler()),
#                 ('linear', LinearRegression(n_jobs=9))])

# %%
pred = pipe_linear_model.predict(X_test)

# %%
train_val(pipe_linear_model, X_train, y_train, X_test, y_test)
# Out:
#              train          test
# R2    9.103304e-01  9.111238e-01
# mae   8.100759e+02  8.070896e+02
# mse   1.421869e+06  1.392721e+06
# rmse  1.192422e+03  1.180136e+03

# %% [markdown]
# ### Cross validation

# %%
model = Pipeline(steps=operations)
scores = cross_validate(model,
                        X_train,
                        y_train,
                        scoring=['r2',
                                'neg_mean_absolute_error',
                                'neg_mean_squared_error',
                                'neg_root_mean_squared_error'],
                        cv = 10,
                        return_train_score=True)

pd.DataFrame(scores)

pd.DataFrame(scores).iloc[:, 2:].mean()
# Out:
# test_r2                              9.102027e-01
# train_r2                             9.103314e-01
# test_neg_mean_absolute_error        -8.102200e+02
# train_neg_mean_absolute_error       -8.100663e+02
# test_neg_mean_squared_error         -1.422499e+06
# train_neg_mean_squared_error        -1.421836e+06
# test_neg_root_mean_squared_error    -1.192594e+03
# train_neg_root_mean_squared_error   -1.192407e+03
# dtype: float64

# %%
from yellowbrick.regressor import PredictionError
from yellowbrick.features import RadViz

visualizer = RadViz(size=(500, 1000))
pipe_linear_model = Pipeline(steps=operations)
visualizer = PredictionError(model)
visualizer.fit(X_train, y_train) # Fit the training data to the visualizer
visualizer.score(X_test, y_test) # Evaluate the model on the test data
visualizer.show();

# %%
from yellowbrick.regressor import ResidualsPlot

visualizer = RadViz(size=(1000, 500))
model = Pipeline(steps=operations)
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train) # Fit the training data to the visualizer
visualizer.score(X_test, y_test) # Evaluate the model on the test data
visualizer.show();

# %%
y_pred=pipe_linear_model.predict(X_test)
y_pred_train = pipe_linear_model.predict(X_train)

residual_test = y_test-y_pred
residual_train = y_train-y_pred_train

plt.figure(figsize=(20,7))
plt.subplot(121)

sns.scatterplot(x = y_pred, y = residual_test, palette="deep", size=2, alpha=0.6)
sns.scatterplot(x = y_pred_train, y = residual_train, size=2, alpha=0.4)

plt.axhline(y = 0, color ="r", linestyle = "--")
plt.ylabel("residuals")
plt.xlabel("y_pred")

plt.subplot(122)

sns.scatterplot(x = y_pred, y = residual_test, palette="deep", size=2, alpha=0.6)
sns.scatterplot(x = y_pred_train, y = residual_train, size=2, alpha=0.4)

plt.axhline(y = 0, color ="r", linestyle = "--")
plt.ylabel("residuals")
plt.xlabel("y_pred")
plt.xlim([-10000,15000])
plt.ylim([-10000,20000])
plt.show();

# %% [markdown]
# ## Random Forest Model

# %%
operations = [
    ("Ordinalencoder", column_trans),
    ('scaler', scaler),
    ("rf",RandomForestRegressor(random_state=101))
]

pipe_rf_model = Pipeline(steps=operations)

pipe_rf_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('Ordinalencoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['D',
#                                                                               'E',
#                                                                               'F',
#                                                                               'G',
#                                                                               'H',
#                                                                               'I',
#                                                                               'J'],
#                                                                              ['IF',
#                                                                               'VVS1',
#                                                                               'VVS2',
#                                                                               'VS1',
#                                                                               'VS2',
#                                                                               'SI1',
#                                                                               'SI2',
#                                                                               'I1']]),
#                                                   ['color', 'clarity'])],
#                                    verbose_feature_names_out=False)),
#                 ('scaler', MinMaxScaler()),
#                 ('rf', RandomForestRegressor(random_state=101))])

# %%
pred = pipe_rf_model.predict(X_test)

# %%
train_val(pipe_rf_model, X_train, y_train, X_test, y_test)
# Out:
#              train           test
# R2        0.995475       0.977515
# mae     146.613504     314.092118
# mse   71755.822123  352352.828564
# rmse    267.872772     593.593151

# %%
fe = train_df.copy()
fe = fe.drop('price', axis=1)
fe.head()
# Out:
#    carat color clarity  Length  width  depth
# 0   1.06     I     SI2    6.57   6.60   4.07
# 1   1.51     G    VVS2    7.38   7.42   4.51
# 2   0.32     F     VS2    4.43   4.41   2.71
# 3   0.53     G     VS2    5.19   5.22   3.19
# 4   0.70     H    VVS2    5.76   5.72   3.50

# %%
features = fe.columns
features
# Out:
# Index(['carat', 'color', 'clarity', 'Length', 'width', 'depth'], dtype='object')

# %%
X_train_rf = column_trans.fit_transform(X_train)
X_train_rf
# Out:
#        color  clarity  carat  Length  width  depth
# 33813    0.0      6.0   0.40    4.71   4.77   2.94
# 12415    0.0      2.0   1.13    6.65   6.68   4.11
# 6171     1.0      6.0   0.43    4.94   4.87   2.99
# 27940    2.0      5.0   0.93    6.25   6.21   3.88
# 11700    3.0      4.0   0.30    4.25   4.28   2.69
# ...      ...      ...    ...     ...    ...    ...
# 12379    3.0      6.0   0.71    5.68   5.63   3.55
# 5700     5.0      4.0   1.30    6.98   7.04   4.33
# 8013     4.0      4.0   1.04    6.56   6.53   3.99
# 17787    4.0      1.0   0.31    4.28   4.32   2.72
# 17973    3.0      3.0   0.50    5.06   5.09   3.19
#
# [34328 rows x 6 columns]

# %%
rf_model = RandomForestRegressor(max_depth=8, max_features=6, n_estimators=400, random_state=101).fit(X_train_rf, y_train)
rf_feature_imp = pd.DataFrame(data=rf_model.feature_importances_,
                              index = features,
                              columns=["Feature Importance"])

rf_feature_imp = rf_feature_imp.sort_values("Feature Importance", ascending=False)
rf_feature_imp
# Out:
#          Feature Importance
# clarity            0.584718
# width              0.315671
# color              0.063811
# carat              0.027913
# Length             0.005269
# depth              0.002619

# %%
#Plotting the feature importance
plt.figure(figsize=(14, 10), dpi=100)
ax = sns.barplot(x=rf_feature_imp["Feature Importance"],
                 y=rf_feature_imp.index)

ax.bar_label(ax.containers[0],fmt="%.3f")
plt.title("Feature Importance for Random Forest")
plt.show()

# %%
'z', 'depth', 'table', 'cut'
# Out:
# ('z', 'depth', 'table', 'cut')

# %%
operations = [
    ("Ordinalencoder", column_trans),
    ('scaler', scaler),
    ("rf",RandomForestRegressor(max_depth=9, n_estimators=400, max_features=9, random_state=101))
]
rf_model = Pipeline(steps=operations)
scores = cross_validate(rf_model,
                        X_train,
                        y_train,
                        scoring=['r2',
                                'neg_mean_absolute_error',
                                'neg_mean_squared_error',
                                'neg_root_mean_squared_error'],
                        cv = 10,
                        return_train_score=True)

pd.DataFrame(scores)

pd.DataFrame(scores).iloc[:, 2:].mean()
# Out:
# test_r2                                   0.979190
# train_r2                                  0.983351
# test_neg_mean_absolute_error           -220.572939
# train_neg_mean_absolute_error          -200.212210
# test_neg_mean_squared_error         -137458.434125
# train_neg_mean_squared_error        -110054.355933
# test_neg_root_mean_squared_error       -370.559271
# train_neg_root_mean_squared_error      -331.741039
# dtype: float64

# %%
operations = [
    ("Ordinalencoder", column_trans),
    ('scaler', scaler),
    ("rf",RandomForestRegressor(n_estimators=400, max_features=4, max_depth=11,  random_state=101))
]

pipe_rf_model2 = Pipeline(steps=operations)

pipe_rf_model2.fit(X_train, y_train)

pred2 = pipe_rf_model.predict(X_test)


train_val(pipe_rf_model2, X_train, y_train, X_test, y_test)
# Out:
#               train           test
# R2         0.986541       0.980394
# mae      252.441379     295.580317
# mse   213421.868861  307231.866445
# rmse     461.976048     554.285005

# %% [markdown]
# ## Final Model

# %%
operations = [
    ("Ordinalencoder", column_trans),
    ('scaler', scaler),
    ("rf",RandomForestRegressor(n_estimators=400, max_features=4, max_depth=11,  random_state=101))
]

final_model = Pipeline(steps=operations)

final_model.fit(X, y)

# train_val(pipe_rf_model2, X_train, y_train, X_test, y_test)
# Out:
# Pipeline(steps=[('Ordinalencoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['D',
#                                                                               'E',
#                                                                               'F',
#                                                                               'G',
#                                                                               'H',
#                                                                               'I',
#                                                                               'J'],
#                                                                              ['IF',
#                                                                               'VVS1',
#                                                                               'VVS2',
#                                                                               'VS1',
#                                                                               'VS2',
#                                                                               'SI1',
#                                                                               'SI2',
#                                                                               'I1']]),
#                                                   ['color', 'clarity'])],
#                                    verbose_feature_names_out=False)),
#                 ('scaler', MinMaxScaler()),
#                 ('rf',
#                  RandomForestRegressor(max_depth=11, max_features=4,
#                                        n_estimators=400, random_state=101))])

# %% [markdown]
# ## Saving the Model

# %%
import pickle
pickle.dump(final_model, open('final_rf', 'wb'))

# %%
import joblib

joblib.dump(final_model, 'final_rf.joblib')
# Out:
# ['final_rf.joblib']

# %%
new_model = pickle.load(open('final_rf', 'rb'))

# %%
train_df.carat.max()
# Out:
# 2.8

# %%
train_df.carat.min()

# %%
pip install tensorflow-model-optimization
# Out:
# Collecting tensorflow-model-optimization
#   Downloading tensorflow_model_optimization-0.8.0-py2.py3-none-any.whl (242 kB)
#                                               0.0/242.5 kB ? eta -:--:--
#      ---                                   20.5/242.5 kB 640.0 kB/s eta 0:00:01
#      ----                                  30.7/242.5 kB 325.1 kB/s eta 0:00:01
#      ---------                             61.4/242.5 kB 465.5 kB/s eta 0:00:01
#      ------------------                   122.9/242.5 kB 717.5 kB/s eta 0:00:01
#      ------------------------------       204.8/242.5 kB 953.7 kB/s eta 0:00:01
#      -------------------------------------- 242.5/242.5 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py~=1.2 in c:\users\habob\anaconda3\lib\site-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in c:\users\habob\anaconda3\lib\site-packages (from tensorflow-model-optimization) (0.1.8)
# Requirement already satisfied: numpy~=1.23 in c:\users\habob\anaconda3\lib\site-packages (from tensorflow-model-optimization) (1.24.3)
# Requirement already satisfied: six~=1.14 in c:\users\habob\anaconda3\lib\site-packages (from tensorflow-model-optimization) (1.16.0)
# Installing collected packages: tensorflow-model-optimization
# Successfully installed tensorflow-model-optimization-0.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow_model_optimization.sparsity import keras as sparsity

# Load the trained model
model = load_model('final_rf')

# Define the pruning parameters
pruning_params = {
    'pruning_schedule': sparsity.PolynomialDecay(initial_sparsity=0.50,
                                                 final_sparsity=0.90,
                                                 begin_step=0,
                                                 end_step=1000)
}

# Apply pruning to the model
pruned_model = sparsity.prune_low_magnitude(model, **pruning_params)

# Retrain the pruned model
pruned_model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
pruned_model.fit(x_train, y_train, epochs=10, validation_data=(x_val, y_val), callbacks=[EarlyStopping()])

# Strip the pruning wrappers
final_model = sparsity.strip_pruning(pruned_model)

# Save the final pruned model
final_model.save('path_to_pruned_model.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16924\1366841398.py in <cell line: 0>()
#       8
#       9 # Load the trained model
# ---> 10 model = load_model('final_rf')
#      11
#      12 # Define the pruning parameters
#
# ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
#     263         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264     )
#
# ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\Lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     565                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                                  fs_page_size=fs_page_size)
# --> 567                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     568
#     569             if isinstance(libver, tuple):
#
# ~\anaconda3\Lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229         if swmr and swmr_support:
#     230             flags |= h5f.ACC_SWMR_READ
# --> 231         fid = h5f.open(name, flags, fapl=fapl)
#     232     elif mode == 'r+':
#     233         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)

# %%
my_dict = {
    'carat': 1.00,
    'color': 'G',
    'clarity': 'SI2', 
    'width': 4,
}

# %%
data = pd.DataFrame.from_dict([my_dict])
data
# Out:
#    carat color clarity  width
# 0    1.0     G     SI2      4

# %%
prediction = new_model.predict(data)
print(prediction)
# Out:
# [2856.25374726]

# %%
print("The estimated price is {}. ".format(int(prediction[0])))
# Out:
# The estimated price is 2856.

# %%
conda env list
# Out:
# # conda environments:
# #
# base                  *  C:\Users\habob\anaconda3
# env_name                 C:\Users\habob\anaconda3\envs\env_name
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: scikit-learn==1.2.2 in c:\users\habob\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: streamlit==1.22.0 in c:\users\habob\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\habob\anaconda3\lib\site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\habob\anaconda3\lib\site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\habob\anaconda3\lib\site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\habob\anaconda3\lib\site-packages (from scikit-learn==1.2.2->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: altair<5,>=3.2.0 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (4.2.2)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: cachetools>=4.0 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (5.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (8.0.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (6.0.0)
# Requirement already satisfied: packaging>=14.1 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pandas<3,>=0.25 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (2.0.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (10.0.1)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (3.20.3)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (11.0.0)
# Requirement already satisfied: pympler>=0.9 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: python-dateutil in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: requests>=2.4 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (8.2.2)
# Requirement already satisfied: toml in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (5.2)
# Requirement already satisfied: validators>=0.2 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (3.1.40)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (0.8.1b0)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (6.3.3)
# Requirement already satisfied: watchdog in c:\users\habob\anaconda3\lib\site-packages (from streamlit==1.22.0->-r requirements.txt (line 2)) (2.1.6)
# Requirement already satisfied: entrypoints in c:\users\habob\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (0.4)
# Requirement already satisfied: jinja2 in c:\users\habob\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\habob\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (4.17.3)
# Requirement already satisfied: toolz in c:\users\habob\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: colorama in c:\users\habob\anaconda3\lib\site-packages (from click>=7.0->streamlit==1.22.0->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\habob\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit==1.22.0->-r requirements.txt (line 2)) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\habob\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit==1.22.0->-r requirements.txt (line 2)) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\habob\anaconda3\lib\site-packages (from pandas<3,>=0.25->streamlit==1.22.0->-r requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\habob\anaconda3\lib\site-packages (from pandas<3,>=0.25->streamlit==1.22.0->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\habob\anaconda3\lib\site-packages (from python-dateutil->streamlit==1.22.0->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\habob\anaconda3\lib\site-packages (from requests>=2.4->streamlit==1.22.0->-r requirements.txt (line 2)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\habob\anaconda3\lib\site-packages (from requests>=2.4->streamlit==1.22.0->-r requirements.txt (line 2)) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\habob\anaconda3\lib\site-packages (from requests>=2.4->streamlit==1.22.0->-r requirements.txt (line 2)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\habob\anaconda3\lib\site-packages (from requests>=2.4->streamlit==1.22.0->-r requirements.txt (line 2)) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\habob\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit==1.22.0->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\habob\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit==1.22.0->-r requirements.txt (line 2)) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\habob\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.22.0->-r requirements.txt (line 2)) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\habob\anaconda3\lib\site-packages (from jinja2->altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\habob\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\habob\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.22.0->-r requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\habob\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->streamlit==1.22.0->-r requirements.txt (line 2)) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !streamlit run my_app.py
# Out:
# ^C

# %%
import numpy as np

# Access the RandomForestRegressor step of the pipeline
random_forest = pipe_rf_model2.named_steps['rf']

# Get feature importances
importances = random_forest.feature_importances_

# Sort feature importances in descending order
sorted_indices = np.argsort(importances)[::-1]

# Define feature names
feature_names = X_train.columns

# Print feature importance ranking
for i in sorted_indices:
    print(f"{feature_names[i]}: {importances[i]}")
# Out:
# clarity: 0.48400809941156486
# y: 0.30831741670606194
# x: 0.08248630040594393
# color: 0.06580232797656381
# carat: 0.03137398597921369
# z: 0.020072278329180907
# depth: 0.003599663261912513
# table: 0.0023063313059752035
# cut: 0.0020335966235831464

# %% [markdown]
# ## RF GridSearch

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
operations = [
    ("Ordinalencoder", column_trans),
    ('scaler', scaler),
    ("rf",RandomForestRegressor(random_state=101))
]


pipeline = Pipeline(steps=operations)


# Define the parameter grid for grid search
param_grid = {
    "rf__n_estimators": [300,400, 500, 600],
    "rf__max_depth": [4, 6,  8],
    'rf__max_features':[4, 6, 8],
}

# param_grid = {'rf__n_estimators':[100,200, 300, 400, 500, 600],
#              'rf__max_features':[2, 4, 6, 8],
#              'rf__max_depth':[2, 4,6, 8],
# #              'rf__min_samples_split':[2, 3, 4, 5],
# #              'rf__min_samples_leaf': [2, 3, 4, 5]
#              }

# Create GridSearchCV object
grid_search = GridSearchCV(pipeline, param_grid=param_grid, cv=5, scoring='neg_root_mean_squared_error')

# Fit the grid search on the training data
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Ordinalencoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(categories=[['D',
#                                                                                                      'E',
#                                                                                                      'F',
#                                                                                                      'G',
#                                                                                                      'H',
#                                                                                                      'I',
#                                                                                                      'J'],
#                                                                                                     ['IF',
#                                                                                                      'VVS1',
#                                                                                                      'VVS2',
#                                                                                                      'VS1',
#                                                                                                      'VS2',
#                                                                                                      'SI1',
#                                                                                                      'SI2',
#                                                                                                      'I1']]),
#                                                                          ['color',
#                                                                           'clarity'])],
#                                                           verbose_feature_names_out=False)),
#                                        ('scaler', MinMaxScaler()),
#                                        ('rf',
#                                         RandomForestRegressor(random_state=101))]),
#              param_grid={'rf__max_depth': [4, 6, 8],
#                          'rf__max_features': [4, 6, 8],
#                          'rf__n_estimators': [300, 400, 500, 600]},
#              scoring='neg_root_mean_squared_error')

# %%
pred = grid_search.predict(X_test)

# %%
train_val(grid_search, X_train, y_train, X_test, y_test)
# Out:
#               train           test
# R2         0.977989       0.976192
# mae      327.789172     336.239033
# mse   349024.369928  373076.725707
# rmse     590.782845     610.800070

# %%
# Get the best model and its score
best_model = grid_search.best_estimator_
best_score = grid_search.best_score_

# Evaluate the best model on the testing data
test_score = best_model.score(X_test, y_test)

# Print the best score and the test score
print("Best Score:", best_score)
print("Test Score:", test_score)

# Print the best parameters
print("Best Parameters:")
print(grid_search.best_params_)
# Out:
# Best Score: -634.1521598230051
# Test Score: 0.9761921957884986
# Best Parameters:
# {'rf__max_depth': 8, 'rf__max_features': 4, 'rf__n_estimators': 400}

# %% [markdown]
# ## XG Boost Model

# %%
y_test

# %%
import xgboost as xgb


operations = [
    ("Ordinalencoder", column_trans),
    ('scaler', scaler),
    ("XGB_model", xgb.XGBRegressor(random_state=101))
]

pipe_xg_model = Pipeline(steps=operations)

pipe_xg_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('Ordinalencoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['D',
#                                                                               'E',
#                                                                               'F',
#                                                                               'G',
#                                                                               'H',
#                                                                               'I',
#                                                                               'J'],
#                                                                              ['Ideal',
#                                                                               'Premium',
#                                                                               'Very '
#                                                                               'Good',
#                                                                               'Good',
#                                                                               'Fair'],
#                                                                              ['IF',
#                                                                               'VVS1',
#                                                                               'VVS2',
#                                                                               'VS1',
#                                                                               'VS2',
#                                                                               'SI1',
#                                                                               'SI2',
#                                                                               'I1']]),
#                                                   ['color', 'cut', 'clarity'])],
#                                    verbose_feature_names_out=False)),
#                 ('scaler', MinMaxScaler()...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=None, n_jobs=None,
#                               num_parallel_tree=None, random_state=101, ...))])

# %%
pred = pipe_xg_model.predict(X_test)

# %%
train_val(pipe_xg_model, X_train, y_train, X_test, y_test)
# Out:
#               train           test
# R2         0.992072       0.981518
# mae      186.567733     244.202529
# mse   100523.824530  230492.247975
# rmse     317.054924     480.096082

# %%
operations = [
    ("Ordinalencoder", column_trans),
    ('scaler', scaler),
    ("XGB_model", xgb.XGBRegressor(random_state=101))
]

xg_model = Pipeline(steps=operations)
scores = cross_validate(xg_model,
                        X_train,
                        y_train,
                        scoring=['r2',
                                'neg_mean_absolute_error',
                                'neg_mean_squared_error',
                                'neg_root_mean_squared_error'],
                        cv = 10,
                        return_train_score=True)

pd.DataFrame(scores)

pd.DataFrame(scores).iloc[:, 2:].mean()
# Out:
# test_r2                                   0.983004
# train_r2                                  0.992498
# test_neg_mean_absolute_error           -242.206574
# train_neg_mean_absolute_error          -181.983239
# test_neg_mean_squared_error         -215330.954346
# train_neg_mean_squared_error         -95128.819541
# test_neg_root_mean_squared_error       -463.813654
# train_neg_root_mean_squared_error      -308.414231
# dtype: float64

# %%
operations = [
    ("Ordinalencoder", column_trans),
#     ('scaler', scaler),
   ("XGB_model", xgb.XGBRegressor(n_estimators=100,subsample=0.9,max_depth=6,random_state=101))
]

pipe_xg_model2 = Pipeline(steps=operations)

pipe_xg_model2.fit(X_train, y_train)

pred2 = pipe_xg_model2.predict(X_test)


train_val(pipe_xg_model2, X_train, y_train, X_test, y_test)
# Out:
#              train           test
# R2        0.992548       0.982163
# mae     185.662332     245.747545
# mse   94496.760946  222453.671105
# rmse    307.403255     471.649946

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
operations = [
    ("Ordinalencoder", column_trans),
#     ('scaler', scaler),
   ("XGB_model", xgb.XGBRegressor(random_state=101))
]



pipeline = Pipeline(steps=operations)


# Define the parameter grid for grid search
param_grid = {
    "rf__n_estimators": [300,400, 500, 600],
    "rf__max_depth": [4, 5, 6, 7, 8, 9],
}

# param_grid = {'rf__n_estimators':[100,200, 300, 400, 500, 600],
#              'rf__max_features':[2, 4, 6, 8],
#              'rf__max_depth':[2, 4,6, 8],
# #              'rf__min_samples_split':[2, 3, 4, 5],
# #              'rf__min_samples_leaf': [2, 3, 4, 5]
#              }

# Create GridSearchCV object
grid_search = GridSearchCV(pipeline, param_grid=param_grid, cv=5, scoring='neg_root_mean_squared_error')

# Fit the grid search on the training data
grid_search.fit(X_train, y_train)

# %%
pred = grid_search.predict(X_test)

# %%
train_val(grid_search, X_train, y_train, X_test, y_test)

# %%
# Get the best model and its score
best_model = grid_search.best_estimator_
best_score = grid_search.best_score_

# Evaluate the best model on the testing data
test_score = best_model.score(X_test, y_test)

# Print the best score and the test score
print("Best Score:", best_score)
print("Test Score:", test_score)

# Print the best parameters
print("Best Parameters:")
print(grid_search.best_params_)

# %% [markdown]
# ## Feature Importance

# %%
df = train_df.drop(['depth', 'table', 'cut'], axis=1)
df.head()
# Out:
#    carat color clarity  price      volume
# 0   1.06     I     SI2   4270  176.483340
# 2   0.32     F     VS2    828   52.943373
# 3   0.53     G     VS2   1577   86.422842
# 4   0.70     H    VVS2   2596  115.315200
# 5   0.90     G      IF   5670  145.652094

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler

cat2 = ['color', 'clarity']
color = ['D', 'E', 'F', 'G', 'H', 'I', 'J']
# cut = ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']
clarity = ['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1']

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

column_trans2 = make_column_transformer((OrdinalEncoder(categories= [color,clarity]),cat2),remainder='passthrough',verbose_feature_names_out=False) # MinMaxScaler()

column_trans2=column_trans2.set_output(transform="pandas")

# %%
X2 = df.drop(columns=["price"])
y2 = df.price

# %%
from sklearn.model_selection import train_test_split

X_train2, X_test2, y_train2, y_test2 = train_test_split(
    X2, y2, test_size=0.2, random_state=101
)

# %%
operations = [
    ("Ordinalencoder", column_trans2),
    ('scaler', scaler),
    ("rf",RandomForestRegressor(n_estimators=400, max_features=6, max_depth=8, random_state=101))
]

pipe_rf_model = Pipeline(steps=operations)

pipe_rf_model.fit(X_train2, y_train2)
# Out:
# Pipeline(steps=[('Ordinalencoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['D',
#                                                                               'E',
#                                                                               'F',
#                                                                               'G',
#                                                                               'H',
#                                                                               'I',
#                                                                               'J'],
#                                                                              ['IF',
#                                                                               'VVS1',
#                                                                               'VVS2',
#                                                                               'VS1',
#                                                                               'VS2',
#                                                                               'SI1',
#                                                                               'SI2',
#                                                                               'I1']]),
#                                                   ['color', 'clarity'])],
#                                    verbose_feature_names_out=False)),
#                 ('scaler', MinMaxScaler()),
#                 ('rf',
#                  RandomForestRegressor(max_depth=8, max_features=6,
#                                        n_estimators=400, random_state=101))])

# %%
pred = pipe_rf_model.predict(X_test2)

# %%
train_val(pipe_rf_model, X_train2, y_train2, X_test2, y_test2)
# Out:
#               train           test
# R2         0.979091       0.976011
# mae      230.078997     242.264450
# mse   140432.657482  163232.058721
# rmse     374.743456     404.019874

# %%
test_df = test_df.drop(['z', 'depth', 'table', 'cut'], axis=1)
test_df.head()
# Out:
#    Id  carat color clarity     x     y
# 0   1   0.34     G    VVS2  4.52  4.48
# 1   2   0.71     E     VS2  5.74  5.68
# 2   3   0.44     I     VS1  4.83  4.88
# 3   4   0.81     E     SI2  6.09  6.03
# 4   5   0.40     G    VVS1  4.74  4.80

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
operations = [
    ("Ordinalencoder", column_trans2),
#     ('scaler', scaler),
    ("rf",RandomForestRegressor(random_state=101))
]


pipeline = Pipeline(steps=operations)


# Define the parameter grid for grid search
param_grid = {
    "rf__n_estimators": [300,400, 500],
    "rf__max_depth": [4, 6,  8],
    'rf__max_features':[4, 6, 8],
}

# param_grid = {'rf__n_estimators':[100,200, 300, 400, 500, 600],
#              'rf__max_features':[2, 4, 6, 8],
#              'rf__max_depth':[2, 4,6, 8],
# #              'rf__min_samples_split':[2, 3, 4, 5],
# #              'rf__min_samples_leaf': [2, 3, 4, 5]
#              }

# Create GridSearchCV object
grid_search2 = GridSearchCV(pipeline, param_grid=param_grid, cv=5, scoring='neg_root_mean_squared_error')

# Fit the grid search on the training data
grid_search2.fit(X_train2, y_train2)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Ordinalencoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(categories=[['D',
#                                                                                                      'E',
#                                                                                                      'F',
#                                                                                                      'G',
#                                                                                                      'H',
#                                                                                                      'I',
#                                                                                                      'J'],
#                                                                                                     ['IF',
#                                                                                                      'VVS1',
#                                                                                                      'VVS2',
#                                                                                                      'VS1',
#                                                                                                      'VS2',
#                                                                                                      'SI1',
#                                                                                                      'SI2',
#                                                                                                      'I1']]),
#                                                                          ['color',
#                                                                           'clarity'])],
#                                                           verbose_feature_names_out=False)),
#                                        ('rf',
#                                         RandomForestRegressor(random_state=101))]),
#              param_grid={'rf__max_depth': [4, 6, 8],
#                          'rf__max_features': [4, 6, 8],
#                          'rf__n_estimators': [300, 400, 500]},
#              scoring='neg_root_mean_squared_error')

# %%
pred = grid_search2.predict(X_test2)

# %%
train_val(grid_search2, X_train2, y_train2, X_test2, y_test2)
# Out:
#               train           test
# R2         0.978877       0.977706
# mae      228.023018     237.486814
# mse   139629.806437  146325.142367
# rmse     373.670719     382.524695

# %%
# Get the best model and its score
best_model = grid_search2.best_estimator_
best_score = grid_search2.best_score_

# Evaluate the best model on the testing data
test_score = best_model.score(X_test2, y_test2)

# Print the best score and the test score
print("Best Score:", best_score)
print("Test Score:", test_score)

# Print the best parameters
print("Best Parameters:")
print(grid_search2.best_params_)
# Out:
# Best Score: -394.65007548918027
# Test Score: 0.9777061413316264
# Best Parameters:
# {'rf__max_depth': 8, 'rf__max_features': 4, 'rf__n_estimators': 500}

# %%
import xgboost as xgb


operations = [
    ("Ordinalencoder", column_trans2),
    ('scaler', scaler),
    ("XGB_model", xgb.XGBRegressor(random_state=101))
]

pipe_xg_model = Pipeline(steps=operations)

pipe_xg_model.fit(X_train2, y_train2)

train_val(pipe_xg_model, X_train2, y_train2, X_test2, y_test2)
# Out:
#               train           test
# R2         0.990497       0.980519
# mae      199.643415     251.873700
# mse   120497.569037  242950.308704
# rmse     347.127598     492.899897

# %% [markdown]
# ## Final Model

# %% [markdown]
# ### RF

# %%
operations = [
    ("Ordinalencoder", column_trans2),
    ('scaler', scaler),
    ("rf",RandomForestRegressor(n_estimators=400, max_features=6, max_depth=8, random_state=101))
]

pipe_rf_model = Pipeline(steps=operations)

pipe_rf_model.fit(X2, y2)
# Out:
# Pipeline(steps=[('Ordinalencoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['D',
#                                                                               'E',
#                                                                               'F',
#                                                                               'G',
#                                                                               'H',
#                                                                               'I',
#                                                                               'J'],
#                                                                              ['IF',
#                                                                               'VVS1',
#                                                                               'VVS2',
#                                                                               'VS1',
#                                                                               'VS2',
#                                                                               'SI1',
#                                                                               'SI2',
#                                                                               'I1']]),
#                                                   ['color', 'clarity'])],
#                                    verbose_feature_names_out=False)),
#                 ('scaler', MinMaxScaler()),
#                 ('rf',
#                  RandomForestRegressor(max_depth=8, max_features=6,
#                                        n_estimators=400, random_state=101))])

# %%
# train_val(pipe_rf_model, X_train2, y_train2, X_test2, y_test2)
# Out:
#               train           test
# R2         0.978591       0.979609
# mae      229.257640     228.214298
# mse   141518.531051  133838.694827
# rmse     376.189488     365.839712

# %%
operations = [
    ("Ordinalencoder", column_trans2),
    ('scaler', scaler),
    ("XGB_model", xgb.XGBRegressor(random_state=101))
]

pipe_xg_model = Pipeline(steps=operations)

# pipe_xg_model.fit(X2, y2)
pipe_xg_model.fit(X_train2, y_train2)
train_val(pipe_rf_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27784\4001872077.py in <cell line: 0>()
#       2     ("Ordinalencoder", column_trans2),
#       3     ('scaler', scaler),
# ----> 4     ("XGB_model", xgb.XGBRegressor(random_state=101))
#       5 ]
#       6
#
# NameError: name 'xgb' is not defined

# %%
operations = [
    ("Ordinalencoder", column_trans2),
    ('scaler', scaler),
    ("XGB_model", xgb.XGBRegressor(random_state=101))
]

pipe_xg_model2 = Pipeline(steps=operations)

pipe_xg_model2.fit(X2, y2)

# train_val(pipe_rf_model2, X_train2, y_train2, X_test2, y_test2)

# %%
ID= test_df['Id']
ID
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 10783    10784
# 10784    10785
# 10785    10786
# 10786    10787
# 10787    10788
# Name: Id, Length: 10788, dtype: int64

# %%
price=grid_search.predict(test_df.drop('Id',axis=1))
data={'ID':ID,'price':price}
sub=pd.DataFrame(data)
sub.to_csv('sub_final_gr_hi_vo.csv',index=False)
